# %%
import os
import time
import numpy as np
import zhusuan as zs
import tensorflow as tf
from utils import load_dataset, save_image_collections

@zs.reuse_variables(scope="encoder")
def build_encoder(x, z_dim, n_z_per_x, std_noise=0):
    bn = zs.BayesianNet()
    h = tf.layers.dense(tf.cast(x, tf.float32), 500, activation=tf.nn.relu)
    h = tf.layers.dense(h, 500, activation=tf.nn.relu)
    z_mean = tf.layers.dense(h, z_dim)
    z_logstd = tf.layers.dense(h, z_dim)
    # z_logstd = tf.layers.dense(h, z_dim)+std_noise
    bn.normal("z", z_mean, logstd=z_logstd, group_ndims=1, n_samples=n_z_per_x)
    return bn


# Decoder model
@zs.meta_bayesian_net(scope="gen", reuse_variables=True)
def build_decoder(x_dim, z_dim, n, n_particles=1):
    print(x_dim)
    bn = zs.BayesianNet()
    z_mean = tf.zeros([n, z_dim])
    z = bn.normal("z", z_mean, std=1.0, group_ndims=1, n_samples=n_particles)
    h = tf.layers.dense(z, 500, activation=tf.nn.relu)
    h = tf.layers.dense(h, 500, activation=tf.nn.relu)
    # For generating images
    x_logits = tf.layers.dense(h, x_dim)
    bn.deterministic("x_mean", tf.sigmoid(x_logits))
    bn.bernoulli("x", x_logits, group_ndims=1)
    return bn
# Out:
# WARNING:tensorflow:From /home/samsepiol/anaconda3/envs/py36/lib/python3.6/site-packages/zhusuan/framework/utils.py:106: The name tf.make_template is deprecated. Please use tf.compat.v1.make_template instead.

# %%
train_image, train_label, test_image, test_label = load_dataset()
print("loaded dataset")
# Out:
# loaded dataset

# %%
x_dim = train_image.shape[1]
z_dim = 40
n = tf.compat.v1.placeholder(tf.int32, shape=[], name="n")
n_particles = tf.compat.v1.placeholder(tf.int32, shape=[], name="n_particles")
x_input = tf.compat.v1.placeholder(tf.float32, shape=[None, x_dim], name="x")
x = tf.cast(tf.less(tf.random.uniform(tf.shape(x_input)), x_input), tf.int32)

# %%
gen = build_decoder(x_dim, z_dim, n, n_particles)
q_net = build_encoder(x, z_dim, n_particles)

lower_bound = zs.variational.elbo(gen, {"x": x}, variational=q_net, axis=0)
cost = tf.reduce_mean(lower_bound.sgvb())
lower_bound = tf.reduce_mean(lower_bound)
is_log_likelihood = tf.reduce_mean(
    zs.is_loglikelihood(gen, {"x": x}, proposal=q_net, axis=0)
)

optimizer = tf.train.AdamOptimizer(learning_rate=0.001)
infer_op = optimizer.minimize(cost)
# Out:
# WARNING:tensorflow:From <ipython-input-1-7f4f9df5a139>:11: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /home/samsepiol/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/samsepiol/anaconda3/envs/py36/lib/python3.6/site-packages/zhusuan/distributions/base.py:258: The name tf.assert_rank is deprecated. Please use tf.compat.v1.assert_rank instead.
#
# WARNING:tensorflow:From /home/samsepiol/anaconda3/envs/py36/lib/python3.6/site-packages/zhusuan/distributions/univariate.py:167: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# 784
# WARNING:tensorflow:From /home/samsepiol/anaconda3/envs/py36/lib/python3.6/site-packages/zhusuan/distributions/univariate.py:100: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/samsepiol/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 784

# %%
epochs = 1000
batch_size = 128
iters = train_image.shape[0] // batch_size
test_freq = 100
test_batch_size = 400
test_iters = test_image.shape[0] // test_batch_size
result_path = "results"
checkpoints_path = "checkpoints"

# used to save checkpoints during training
saver = tf.train.Saver(max_to_keep=10)
save_model_freq = 100

# %%
# run the inference
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    # restore the model parameters from the latest checkpoint
    ckpt_file = tf.train.latest_checkpoint(checkpoints_path)
    begin_epoch = 1
    if ckpt_file is not None:
        print('Restoring model from {}...'.format(ckpt_file))
        begin_epoch = int(ckpt_file.split('.')[-2]) + 1
        saver.restore(sess, ckpt_file)

    # begin training
    for epoch in range(begin_epoch, epochs + 1):
        time_epoch = -time.time()
        np.random.shuffle(train_image)
        lbs = []
        for t in range(iters):
            x_batch = train_image[t * batch_size:(t + 1) * batch_size]
            _, lb = sess.run([infer_op, lower_bound],
                                feed_dict={x_input: x_batch,
                                        n_particles: 1,
                                        n: batch_size})
            lbs.append(lb)
        time_epoch += time.time()
        print("Epoch {} ({:.1f}s): Lower bound = {}".format(
            epoch, time_epoch, np.mean(lbs)))

        # test marginal log likelihood
        if epoch % test_freq == 0:
            time_test = -time.time()
            test_lbs, test_lls = [], []
            for t in range(test_iters):
                test_x_batch = test_image[t * test_batch_size:
                                        (t + 1) * test_batch_size]
                test_lb = sess.run(lower_bound,
                                    feed_dict={x: test_x_batch,
                                                n_particles: 1,
                                                n: test_batch_size})
                test_ll = sess.run(is_log_likelihood,
                                    feed_dict={x: test_x_batch,
                                                n_particles: 1000,
                                                n: test_batch_size})
                test_lbs.append(test_lb)
                test_lls.append(test_ll)
            time_test += time.time()
            print(">>> TEST ({:.1f}s)".format(time_test))
            print(">> Test lower bound = {}".format(np.mean(test_lbs)))
            print('>> Test log likelihood (IS) = {}'.format(
                np.mean(test_lls)))

        # save model parameters
        if epoch % save_model_freq == 0:
            print('Saving model...')
            save_path = os.path.join(checkpoints_path,
                                        "vae.epoch.{}.ckpt".format(epoch))
            if not os.path.exists(os.path.dirname(save_path)):
                os.makedirs(os.path.dirname(save_path))
            saver.save(sess, save_path)
            print('Done')

    # random generation of images from latent distribution
    x_gen = tf.reshape(gen.observe()["x_mean"], [-1, 28, 28, 1])
    images = sess.run(x_gen, feed_dict={n: 100, n_particles: 1})
    name = os.path.join(result_path, "random_samples.png")
    save_image_collections(images, name)

    # the following code generates 100 samples for each number
    test_n = [3, 2, 1, 90, 95, 23, 11, 0, 84, 7]
    # map each digit to a corresponding sample from the test set so we can generate similar digits
    for i in range(len(test_n)):
        # get latent distribution from the variational giving as input a fixed sample from the dataset
        z = q_net.observe(x=np.expand_dims(test_image[test_n[i]], 0))['z']
        # run the computation graph adding noise to computed variance to get different output samples
        latent = sess.run(z, feed_dict={x_input: np.expand_dims(test_image[test_n[i]], 0),
                                        n: 1,
                                        n_particles: 100})
        # get the image from the model giving as input the latent distribution z
        x_gen = tf.reshape(gen.observe(z=latent)["x_mean"], [-1, 28, 28, 1])
        images = sess.run(x_gen, feed_dict={})
        name = os.path.join(result_path, "{}.png".format(i))
        save_image_collections(images, name)
# Out:
# .7s): Lower bound = -91.31271362304688
# Epoch 618 (2.8s): Lower bound = -91.29603576660156
# Epoch 619 (2.7s): Lower bound = -91.34070587158203
# Epoch 620 (2.7s): Lower bound = -91.26602935791016
# Epoch 621 (2.7s): Lower bound = -91.3501205444336
# Epoch 622 (2.7s): Lower bound = -91.43496704101562
# Epoch 623 (2.7s): Lower bound = -91.332275390625
# Epoch 624 (2.7s): Lower bound = -91.401123046875
# Epoch 625 (2.8s): Lower bound = -91.36964416503906
# Epoch 626 (2.7s): Lower bound = -91.33104705810547
# Epoch 627 (2.7s): Lower bound = -91.33584594726562
# Epoch 628 (2.7s): Lower bound = -91.33245086669922
# Epoch 629 (2.7s): Lower bound = -91.33218383789062
# Epoch 630 (2.7s): Lower bound = -91.39369201660156
# Epoch 631 (2.7s): Lower bound = -91.28287506103516
# Epoch 632 (2.7s): Lower bound = -91.38896179199219
# Epoch 633 (2.7s): Lower bound = -91.34144592285156
# Epoch 634 (2.7s): Lower bound = -91.29479217529297
# Epoch 635 (2.7s): Lower bound = -91.36551666259766
# Epoch 636 (2.7s): Lower bound = -91.36283874511719
# Epoch 637 (2.7s): Lower bound = -91.33527374267578
# Epoch 638 (2.7s): Lower bound = -91.34637451171875
# Epoch 639 (2.7s): Lower bound = -91.33197021484375
# Epoch 640 (2.7s): Lower bound = -91.26668548583984
# Epoch 641 (2.7s): Lower bound = -91.223388671875
# Epoch 642 (2.7s): Lower bound = -91.36314392089844
# Epoch 643 (2.7s): Lower bound = -91.35389709472656
# Epoch 644 (2.7s): Lower bound = -91.28048706054688
# Epoch 645 (2.7s): Lower bound = -91.33808135986328
# Epoch 646 (2.7s): Lower bound = -91.30164337158203
# Epoch 647 (2.7s): Lower bound = -91.32772064208984
# Epoch 648 (2.7s): Lower bound = -91.23148345947266
# Epoch 649 (2.7s): Lower bound = -91.33924102783203
# Epoch 650 (2.8s): Lower bound = -91.31608581542969
# Epoch 651 (2.7s): Lower bound = -91.3552474975586
# Epoch 652 (2.7s): Lower bound = -91.29533386230469
# Epoch 653 (2.7s): Lower bound = -91.27200317382812
# Epoch 654 (2.7s): Lower bound = -91.28783416748047
# Epoch 655 (2.7s): Lower bound = -91.300048828125
# Epoch 656 (2.7s): Lower bound = -91.21664428710938
# Epoch 657 (2.7s): Lower bound = -91.25489044189453
# Epoch 658 (2.7s): Lower bound = -91.30228424072266
# Epoch 659 (2.7s): Lower bound = -91.34672546386719
# Epoch 660 (2.7s): Lower bound = -91.29761505126953
# Epoch 661 (2.7s): Lower bound = -91.31338500976562
# Epoch 662 (2.7s): Lower bound = -91.28531646728516
# Epoch 663 (2.7s): Lower bound = -91.26361083984375
# Epoch 664 (2.7s): Lower bound = -91.21554565429688
# Epoch 665 (2.7s): Lower bound = -91.28617858886719
# Epoch 666 (2.8s): Lower bound = -91.2935562133789
# Epoch 667 (2.7s): Lower bound = -91.23754119873047
# Epoch 668 (2.7s): Lower bound = -91.30622863769531
# Epoch 669 (2.8s): Lower bound = -91.33383178710938
# Epoch 670 (2.8s): Lower bound = -91.22630310058594
# Epoch 671 (2.7s): Lower bound = -91.30309295654297
# Epoch 672 (2.7s): Lower bound = -91.27099609375
# Epoch 673 (2.7s): Lower bound = -91.22425842285156
# Epoch 674 (2.7s): Lower bound = -91.32622528076172
# Epoch 675 (2.7s): Lower bound = -91.26480102539062
# Epoch 676 (2.7s): Lower bound = -91.2293472290039
# Epoch 677 (2.8s): Lower bound = -91.29036712646484
# Epoch 678 (2.8s): Lower bound = -91.29857635498047
# Epoch 679 (2.7s): Lower bound = -91.29345703125
# Epoch 680 (2.7s): Lower bound = -91.23773956298828
# Epoch 681 (2.7s): Lower bound = -91.32575225830078
# Epoch 682 (2.7s): Lower bound = -91.29524993896484
# Epoch 683 (2.7s): Lower bound = -91.21112060546875
# Epoch 684 (2.7s): Lower bound = -91.27730560302734
# Epoch 685 (2.7s): Lower bound = -91.19567108154297
# Epoch 686 (2.7s): Lower bound = -91.18769836425781
# Epoch 687 (2.7s): Lower bound = -91.2655258178711
# Epoch 688 (2.7s): Lower bound = -91.24813079833984
# Epoch 689 (2.7s): Lower bound = -91.29683685302734
# Epoch 690 (2.7s): Lower bound = -91.30648803710938
# Epoch 691 (2.7s): Lower bound = -91.2796859741211
# Epoch 692 (2.7s): Lower bound = -91.26484680175781
# Epoch 693 (2.7s): Lower bound = -91.27881622314453
# Epoch 694 (2.7s): Lower bound = -91.21546173095703
# Epoch 695 (2.7s): Lower bound = -91.29444122314453
# Epoch 696 (2.7s): Lower bound = -91.31402587890625
# Epoch 697 (2.7s): Lower bound = -91.25963592529297
# Epoch 698 (2.7s): Lower bound = -91.22071075439453
# Epoch 699 (2.7s): Lower bound = -91.30657196044922
# Epoch 700 (2.7s): Lower bound = -91.3165283203125
# >>> TEST (90.0s)
# >> Test lower bound = -36.295528411865234
# >> Test log likelihood (IS) = -26.991254806518555
# Saving model...
# Done
# Epoch 701 (2.8s): Lower bound = -91.22015380859375
# Epoch 702 (2.8s): Lower bound = -91.24586486816406
# Epoch 703 (2.7s): Lower bound = -91.20114135742188
# Epoch 704 (2.7s): Lower bound = -91.25652313232422
# Epoch 705 (2.7s): Lower bound = -91.24625396728516
# Epoch 706 (2.7s): Lower bound = -91.17610168457031
# Epoch 707 (2.7s): Lower bound = -91.29444885253906
# Epoch 708 (2.7s): Lower bound = -91.25450897216797
# Epoch 709 (2.7s): Lower bound = -91.2706298828125
# Epoch 710 (2.7s): Lower bound = -91.26091003417969
# Epoch 711 (2.8s): Lower bound = -91.22276306152344
# Epoch 712 (2.8s): Lower bound = -91.3153076171875
# Epoch 713 (2.7s): Lower bound = -91.22349548339844
# Epoch 714 (2.7s): Lower bound = -91.2220230102539
# Epoch 715 (2.7s): Lower bound = -91.20379638671875
# Epoch 716 (2.7s): Lower bound = -91.23402404785156
# Epoch 717 (2.7s): Lower bound = -91.26095581054688
# Epoch 718 (2.7s): Lower bound = -91.22419738769531
# Epoch 719 (2.7s): Lower bound = -91.17623901367188
# Epoch 720 (2.7s): Lower bound = -91.23495483398438
# Epoch 721 (2.8s): Lower bound = -91.20934295654297
# Epoch 722 (2.7s): Lower bound = -91.22682189941406
# Epoch 723 (2.7s): Lower bound = -91.12560272216797
# Epoch 724 (2.7s): Lower bound = -91.15660095214844
# Epoch 725 (2.7s): Lower bound = -91.20729064941406
# Epoch 726 (2.9s): Lower bound = -91.19735717773438
# Epoch 727 (2.8s): Lower bound = -91.1760482788086
# Epoch 728 (2.7s): Lower bound = -91.20927429199219
# Epoch 729 (2.7s): Lower bound = -91.17935943603516
# Epoch 730 (2.7s): Lower bound = -91.25148010253906
# Epoch 731 (2.8s): Lower bound = -91.26226043701172
# Epoch 732 (2.7s): Lower bound = -91.22223663330078
# Epoch 733 (2.7s): Lower bound = -91.21183013916016
# Epoch 734 (2.7s): Lower bound = -91.23008728027344
# Epoch 735 (2.7s): Lower bound = -91.15454864501953
# Epoch 736 (2.7s): Lower bound = -91.1314926147461
# Epoch 737 (2.7s): Lower bound = -91.15276336669922
# Epoch 738 (2.8s): Lower bound = -91.22928619384766
# Epoch 739 (2.7s): Lower bound = -91.18135833740234
# Epoch 740 (2.7s): Lower bound = -91.15221405029297
# Epoch 741 (2.7s): Lower bound = -91.2281265258789
# Epoch 742 (2.7s): Lower bound = -91.1184310913086
# Epoch 743 (2.7s): Lower bound = -91.22183227539062
# Epoch 744 (2.7s): Lower bound = -91.15003967285156
# Epoch 745 (2.7s): Lower bound = -91.1690902709961
# Epoch 746 (2.7s): Lower bound = -91.18035125732422
# Epoch 747 (2.7s): Lower bound = -91.20340728759766
# Epoch 748 (2.7s): Lower bound = -91.15686798095703
# Epoch 749 (2.7s): Lower bound = -91.19149017333984
# Epoch 750 (2.7s): Lower bound = -91.26779174804688
# Epoch 751 (2.7s): Lower bound = -91.1627426147461
# Epoch 752 (2.7s): Lower bound = -91.20668029785156
# Epoch 753 (2.7s): Lower bound = -91.17623138427734
# Epoch 754 (2.7s): Lower bound = -91.20486450195312
# Epoch 755 (2.7s): Lower bound = -91.23343658447266
# Epoch 756 (2.7s): Lower bound = -91.18535614013672
# Epoch 757 (2.7s): Lower bound = -91.15270233154297
# Epoch 758 (2.7s): Lower bound = -91.19944763183594
# Epoch 759 (2.7s): Lower bound = -91.19813537597656
# Epoch 760 (2.8s): Lower bound = -91.14398193359375
# Epoch 761 (2.7s): Lower bound = -91.11975860595703
# Epoch 762 (2.7s): Lower bound = -91.16439056396484
# Epoch 763 (2.7s): Lower bound = -91.18689727783203
# Epoch 764 (2.7s): Lower bound = -91.1142807006836
# Epoch 765 (2.7s): Lower bound = -91.1174545288086
# Epoch 766 (2.7s): Lower bound = -91.11949157714844
# Epoch 767 (2.7s): Lower bound = -91.2555160522461
# Epoch 768 (2.8s): Lower bound = -91.10276794433594
# Epoch 769 (2.7s): Lower bound = -91.13390350341797
# Epoch 770 (2.7s): Lower bound = -91.15945434570312
# Epoch 771 (2.8s): Lower bound = -91.16793060302734
# Epoch 772 (2.7s): Lower bound = -91.19393157958984
# Epoch 773 (2.7s): Lower bound = -91.13770294189453
# Epoch 774 (2.7s): Lower bound = -91.18852233886719
# Epoch 775 (2.7s): Lower bound = -91.14787292480469
# Epoch 776 (2.7s): Lower bound = -91.1557388305664
# Epoch 777 (2.7s): Lower bound = -91.238525390625
# Epoch 778 (2.7s): Lower bound = -91.12816619873047
# Epoch 779 (2.8s): Lower bound = -91.16319274902344
# Epoch 780 (2.8s): Lower bound = -91.13595581054688
# Epoch 781 (2.7s): Lower bound = -91.1739273071289
# Epoch 782 (2.8s): Lower bound = -91.1956558227539
# Epoch 783 (2.7s): Lower bound = -91.12735748291016
# Epoch 784 (2.7s): Lower bound = -91.09807586669922
# Epoch 785 (2.7s): Lower bound = -91.14471435546875
# Epoch 786 (2.7s): Lower bound = -91.14501190185547
# Epoch 787 (2.7s): Lower bound = -91.20282745361328
# Epoch 788 (2.7s): Lower bound = -91.21158599853516
# Epoch 789 (2.7s): Lower bound = -91.11767578125
# Epoch 790 (2.7s): Lower bound = -91.14794921875
# Epoch 791 (2.7s): Lower bound = -91.143310546875
# Epoch 792 (2.7s): Lower bound = -91.15880584716797
# Epoch 793 (2.7s): Lower bound = -91.11943054199219
# Epoch 794 (2.7s): Lower bound = -91.15925598144531
# Epoch 795 (2.7s): Lower bound = -91.15359497070312
# Epoch 796 (2.7s): Lower bound = -91.11648559570312
# Epoch 797 (2.7s): Lower bound = -91.11366271972656
# Epoch 798 (2.7s): Lower bound = -91.10658264160156
# Epoch 799 (2.7s): Lower bound = -91.11699676513672
# Epoch 800 (2.7s): Lower bound = -91.16666412353516
# >>> TEST (88.8s)
# >> Test lower bound = -37.024749755859375
# >> Test log likelihood (IS) = -28.115434646606445
# Saving model...
# Done
# Epoch 801 (2.8s): Lower bound = -91.08744049072266
# Epoch 802 (2.7s): Lower bound = -91.10489654541016
# Epoch 803 (2.7s): Lower bound = -91.12993621826172
# Epoch 804 (2.7s): Lower bound = -91.12451171875
# Epoch 805 (2.8s): Lower bound = -91.16509246826172
# Epoch 806 (2.7s): Lower bound = -91.12864685058594
# Epoch 807 (2.7s): Lower bound = -91.11504364013672
# Epoch 808 (2.7s): Lower bound = -91.0716323852539
# Epoch 809 (2.7s): Lower bound = -91.15745544433594
# Epoch 810 (2.7s): Lower bound = -91.1145248413086
# Epoch 811 (2.7s): Lower bound = -91.09224700927734
# Epoch 812 (2.7s): Lower bound = -91.04084777832031
# Epoch 813 (2.7s): Lower bound = -91.12525177001953
# Epoch 814 (2.8s): Lower bound = -91.10086822509766
# Epoch 815 (2.8s): Lower bound = -91.13265228271484
# Epoch 816 (2.7s): Lower bound = -91.09085845947266
# Epoch 817 (2.7s): Lower bound = -91.07237243652344
# Epoch 818 (2.7s): Lower bound = -91.08097076416016
# Epoch 819 (2.7s): Lower bound = -91.12518310546875
# Epoch 820 (2.7s): Lower bound = -91.12564849853516
# Epoch 821 (2.7s): Lower bound = -91.11312103271484
# Epoch 822 (2.7s): Lower bound = -91.12922668457031
# Epoch 823 (2.7s): Lower bound = -91.15361785888672
# Epoch 824 (2.7s): Lower bound = -91.11558532714844
# Epoch 825 (2.7s): Lower bound = -91.06730651855469
# Epoch 826 (2.7s): Lower bound = -91.10635375976562
# Epoch 827 (2.7s): Lower bound = -91.02666473388672
# Epoch 828 (2.7s): Lower bound = -91.01358795166016
# Epoch 829 (2.7s): Lower bound = -90.98744201660156
# Epoch 830 (2.7s): Lower bound = -91.09137725830078
# Epoch 831 (2.7s): Lower bound = -91.0678482055664
# Epoch 832 (2.7s): Lower bound = -91.14582061767578
# Epoch 833 (2.7s): Lower bound = -91.07127380371094
# Epoch 834 (2.7s): Lower bound = -91.04710388183594
# Epoch 835 (2.7s): Lower bound = -91.04744720458984
# Epoch 836 (2.7s): Lower bound = -91.03118896484375
# Epoch 837 (2.7s): Lower bound = -91.05653381347656
# Epoch 838 (2.7s): Lower bound = -91.09683227539062
# Epoch 839 (2.7s): Lower bound = -91.11564636230469
# Epoch 840 (2.7s): Lower bound = -91.12342071533203
# Epoch 841 (2.7s): Lower bound = -91.0868911743164
# Epoch 842 (2.7s): Lower bound = -91.06143188476562
# Epoch 843 (2.7s): Lower bound = -91.1016845703125
# Epoch 844 (2.7s): Lower bound = -91.17259979248047
# Epoch 845 (2.7s): Lower bound = -91.08709716796875
# Epoch 846 (2.7s): Lower bound = -91.15890502929688
# Epoch 847 (2.7s): Lower bound = -91.05635070800781
# Epoch 848 (2.7s): Lower bound = -91.10066223144531
# Epoch 849 (2.7s): Lower bound = -91.1076431274414
# Epoch 850 (2.7s): Lower bound = -91.05868530273438
# Epoch 851 (2.7s): Lower bound = -91.05657958984375
# Epoch 852 (2.7s): Lower bound = -91.070068359375
# Epoch 853 (2.7s): Lower bound = -91.07524108886719
# Epoch 854 (2.7s): Lower bound = -91.1009521484375
# Epoch 855 (2.7s): Lower bound = -91.11087036132812
# Epoch 856 (2.7s): Lower bound = -91.0357437133789
# Epoch 857 (2.7s): Lower bound = -91.07691192626953
# Epoch 858 (2.7s): Lower bound = -91.02603912353516
# Epoch 859 (2.8s): Lower bound = -91.05415344238281
# Epoch 860 (2.7s): Lower bound = -91.10750579833984
# Epoch 861 (2.7s): Lower bound = -91.08641815185547
# Epoch 862 (2.7s): Lower bound = -91.06436157226562
# Epoch 863 (2.7s): Lower bound = -91.11502075195312
# Epoch 864 (2.7s): Lower bound = -91.05536651611328
# Epoch 865 (2.7s): Lower bound = -91.11282348632812
# Epoch 866 (2.7s): Lower bound = -91.08228302001953
# Epoch 867 (2.7s): Lower bound = -91.0514907836914
# Epoch 868 (2.7s): Lower bound = -91.0081558227539
# Epoch 869 (2.7s): Lower bound = -91.09649658203125
# Epoch 870 (2.7s): Lower bound = -91.03777313232422
# Epoch 871 (2.7s): Lower bound = -91.16740417480469
# Epoch 872 (2.7s): Lower bound = -91.10832977294922
# Epoch 873 (2.7s): Lower bound = -91.01232147216797
# Epoch 874 (2.7s): Lower bound = -91.02852630615234
# Epoch 875 (2.7s): Lower bound = -91.0260238647461
# Epoch 876 (2.7s): Lower bound = -91.06633758544922
# Epoch 877 (2.7s): Lower bound = -91.05564880371094
# Epoch 878 (2.7s): Lower bound = -90.98809051513672
# Epoch 879 (2.7s): Lower bound = -91.04830932617188
# Epoch 880 (2.7s): Lower bound = -91.03768157958984
# Epoch 881 (2.8s): Lower bound = -91.08802795410156
# Epoch 882 (2.8s): Lower bound = -91.07759094238281
# Epoch 883 (2.8s): Lower bound = -91.02088165283203
# Epoch 884 (2.7s): Lower bound = -91.04731750488281
# Epoch 885 (2.7s): Lower bound = -90.97870635986328
# Epoch 886 (2.7s): Lower bound = -91.0072021484375
# Epoch 887 (2.7s): Lower bound = -91.08635711669922
# Epoch 888 (2.7s): Lower bound = -91.01392364501953
# Epoch 889 (2.7s): Lower bound = -91.02256774902344
# Epoch 890 (2.7s): Lower bound = -91.09276580810547
# Epoch 891 (2.7s): Lower bound = -91.0696792602539
# Epoch 892 (2.7s): Lower bound = -91.07486724853516
# Epoch 893 (2.7s): Lower bound = -90.97578430175781
# Epoch 894 (2.7s): Lower bound = -90.95658111572266
# Epoch 895 (2.7s): Lower bound = -91.04219055175781
# Epoch 896 (2.7s): Lower bound = -91.01981353759766
# Epoch 897 (2.7s): Lower bound = -91.0456314086914
# Epoch 898 (2.7s): Lower bound = -90.98408508300781
# Epoch 899 (2.7s): Lower bound = -91.019287109375
# Epoch 900 (2.7s): Lower bound = -90.99742889404297
# >>> TEST (90.7s)
# >> Test lower bound = -37.69648361206055
# >> Test log likelihood (IS) = -29.364473342895508
# Saving model...
# Done
# Epoch 901 (2.8s): Lower bound = -91.07595825195312
# Epoch 902 (2.7s): Lower bound = -91.0193099975586
# Epoch 903 (2.7s): Lower bound = -91.01971435546875
# Epoch 904 (2.8s): Lower bound = -90.96781158447266
# Epoch 905 (2.7s): Lower bound = -91.03915405273438
# Epoch 906 (2.7s): Lower bound = -91.00409698486328
# Epoch 907 (2.7s): Lower bound = -90.9963150024414
# Epoch 908 (2.7s): Lower bound = -90.95777893066406
# Epoch 909 (2.7s): Lower bound = -90.95306396484375
# Epoch 910 (2.7s): Lower bound = -91.03179168701172
# Epoch 911 (2.8s): Lower bound = -90.97898864746094
# Epoch 912 (2.7s): Lower bound = -90.95877075195312
# Epoch 913 (2.8s): Lower bound = -91.03106689453125
# Epoch 914 (2.8s): Lower bound = -90.9707260131836
# Epoch 915 (2.7s): Lower bound = -91.00971221923828
# Epoch 916 (2.7s): Lower bound = -91.08162689208984
# Epoch 917 (2.8s): Lower bound = -90.96356964111328
# Epoch 918 (2.7s): Lower bound = -91.01811981201172
# Epoch 919 (2.7s): Lower bound = -91.03175354003906
# Epoch 920 (2.7s): Lower bound = -91.0201416015625
# Epoch 921 (2.7s): Lower bound = -90.98575592041016
# Epoch 922 (2.7s): Lower bound = -90.98584747314453
# Epoch 923 (2.8s): Lower bound = -91.04415130615234
# Epoch 924 (2.7s): Lower bound = -91.01516723632812
# Epoch 925 (2.8s): Lower bound = -91.09278869628906
# Epoch 926 (2.7s): Lower bound = -91.03125
# Epoch 927 (2.7s): Lower bound = -90.99759674072266
# Epoch 928 (2.7s): Lower bound = -91.0089340209961
# Epoch 929 (2.8s): Lower bound = -91.05193328857422
# Epoch 930 (2.7s): Lower bound = -90.97177124023438
# Epoch 931 (2.7s): Lower bound = -91.01789093017578
# Epoch 932 (2.7s): Lower bound = -91.01863098144531
# Epoch 933 (2.7s): Lower bound = -91.02117156982422
# Epoch 934 (2.7s): Lower bound = -90.9556884765625
# Epoch 935 (2.7s): Lower bound = -91.07225799560547
# Epoch 936 (2.7s): Lower bound = -90.94245910644531
# Epoch 937 (2.7s): Lower bound = -90.96785736083984
# Epoch 938 (2.7s): Lower bound = -91.1106185913086
# Epoch 939 (2.8s): Lower bound = -90.9443130493164
# Epoch 940 (2.7s): Lower bound = -91.01207733154297
# Epoch 941 (2.7s): Lower bound = -91.00292205810547
# Epoch 942 (2.7s): Lower bound = -90.970703125
# Epoch 943 (2.7s): Lower bound = -90.9791259765625
# Epoch 944 (2.7s): Lower bound = -91.02413177490234
# Epoch 945 (2.7s): Lower bound = -90.95323181152344
# Epoch 946 (2.7s): Lower bound = -90.92351531982422
# Epoch 947 (2.7s): Lower bound = -91.02157592773438
# Epoch 948 (2.7s): Lower bound = -90.93954467773438
# Epoch 949 (2.7s): Lower bound = -90.98712158203125
# Epoch 950 (2.7s): Lower bound = -90.95050048828125
# Epoch 951 (2.8s): Lower bound = -91.07598114013672
# Epoch 952 (2.8s): Lower bound = -90.97930908203125
# Epoch 953 (2.7s): Lower bound = -90.96442413330078
# Epoch 954 (2.7s): Lower bound = -90.9130630493164
# Epoch 955 (2.8s): Lower bound = -90.95228576660156
# Epoch 956 (2.8s): Lower bound = -90.9493179321289
# Epoch 957 (2.8s): Lower bound = -90.99810028076172
# Epoch 958 (2.7s): Lower bound = -90.96897888183594
# Epoch 959 (2.7s): Lower bound = -90.93517303466797
# Epoch 960 (2.8s): Lower bound = -91.00344848632812
# Epoch 961 (2.8s): Lower bound = -90.97589874267578
# Epoch 962 (2.7s): Lower bound = -90.93800354003906
# Epoch 963 (2.8s): Lower bound = -90.97248840332031
# Epoch 964 (2.7s): Lower bound = -91.01763153076172
# Epoch 965 (2.7s): Lower bound = -90.93822479248047
# Epoch 966 (2.7s): Lower bound = -90.97962951660156
# Epoch 967 (2.7s): Lower bound = -90.95186614990234
# Epoch 968 (2.7s): Lower bound = -90.97702026367188
# Epoch 969 (2.7s): Lower bound = -90.91389465332031
# Epoch 970 (2.7s): Lower bound = -90.91120147705078
# Epoch 971 (2.7s): Lower bound = -90.93377685546875
# Epoch 972 (2.7s): Lower bound = -90.95382690429688
# Epoch 973 (2.8s): Lower bound = -91.00994873046875
# Epoch 974 (2.7s): Lower bound = -90.95087432861328
# Epoch 975 (2.7s): Lower bound = -90.9244155883789
# Epoch 976 (2.8s): Lower bound = -91.0035629272461
# Epoch 977 (2.7s): Lower bound = -90.9101333618164
# Epoch 978 (2.7s): Lower bound = -90.97010040283203
# Epoch 979 (2.7s): Lower bound = -90.98799896240234
# Epoch 980 (2.7s): Lower bound = -90.97199249267578
# Epoch 981 (2.7s): Lower bound = -90.93172454833984
# Epoch 982 (2.7s): Lower bound = -90.95967864990234
# Epoch 983 (2.7s): Lower bound = -91.02306365966797
# Epoch 984 (2.7s): Lower bound = -90.94218444824219
# Epoch 985 (2.8s): Lower bound = -90.97682189941406
# Epoch 986 (2.7s): Lower bound = -90.96749114990234
# Epoch 987 (2.7s): Lower bound = -90.92245483398438
# Epoch 988 (2.8s): Lower bound = -90.88307189941406
# Epoch 989 (2.7s): Lower bound = -91.00767517089844
# Epoch 990 (2.7s): Lower bound = -90.94762420654297
# Epoch 991 (2.7s): Lower bound = -90.89686584472656
# Epoch 992 (2.7s): Lower bound = -90.94448852539062
# Epoch 993 (2.7s): Lower bound = -90.92827606201172
# Epoch 994 (2.7s): Lower bound = -90.92720031738281
# Epoch 995 (2.7s): Lower bound = -90.90983581542969
# Epoch 996 (2.8s): Lower bound = -90.90028381347656
# Epoch 997 (2.7s): Lower bound = -90.93004608154297
# Epoch 998 (2.8s): Lower bound = -90.86251831054688
# Epoch 999 (2.7s): Lower bound = -90.91744995117188
# Epoch 1000 (2.8s): Lower bound = -90.98849487304688
# >>> TEST (89.2s)
# >> Test lower bound = -41.28477478027344
# >> Test log likelihood (IS) = -28.958816528320312
# Saving model...
# Done
# 784
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-bb1d3e829645> in <module>
#      70     for i in range(len(test_n)):
#      71         # get latent distribution from the variational giving as input a fixed sample from the dataset
# ---> 72         z = q_net.observe(x=np.expand_dims(test_image[test_n[i]], 0))['z']
#      73         # run the computation graph adding noise to computed variance to get different output samples
#      74         latent = sess.run(z, feed_dict={x_input: np.expand_dims(test_image[test_n[i]], 0),
#
# AttributeError: 'BayesianNet' object has no attribute 'observe'
